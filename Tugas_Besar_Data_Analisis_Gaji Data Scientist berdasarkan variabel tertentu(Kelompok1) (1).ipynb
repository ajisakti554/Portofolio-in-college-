# %% [markdown]
# <a href="https://colab.research.google.com/github/ajisakti554/Pemograman-lanjut/blob/main/Tugas_Besar_Data_Analisis(Kelompok1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TUGAS BESAR DATA ANALYST
#
# Kelompok 1 :
#
#
# 1. Aji Sakti Saputra
# 2. Fadhli jahfal
# 3. Rafid Farhan
# 4. Riyan Putra

# %% [markdown]
# **Menganalisis Gaji pekerjaan sebagai Data Sciencetist Dari tahun 2020-2024 Di seluruh Dunia**

# %%
#menggunakan Library Pandas dan Seaborn
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTJ7xBQatjweuBlGqcKv4_KNsz1uFtH--dMPewKRSQTEocqKDJ7SVJEnnaMirctLOGuVIk6GtDkpYr7/pub?gid=80702269&single=true&output=csv')
#df = merupakan struktur data utama dalam Pandas yang memungkinkan untuk menyimpan data, manipulasi, analisis, dan visualisasi data  dengan mudah(df=Data Frame)
#Memasukan data ke dalam program/google colab

# %%
df.head()

#Untuk menampilkan beberapa baris data yg sudah di insert sebelumnya
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# ...

# %% [markdown]
# # MERUBAH DATA KOLOM/BARIS AGAR LEBIH MUDAH DI ANALISIS

# %%
df.rename(columns={ #Mengubah nama data di dalam kolom, dengan tujuan agar mudah dibaca dan dianalisis
    'Unnamed: 0':'Index',
    'work_year':'Tahun_kerja',
    'experience_level':'Level_pengalaman',
    'employment_type':'Jenis_pekerjaan',
    'job_title':'Jabatan',
    'salary':'Gaji',
    'salary_currency':'Mata_uang',
    'salary_in_usd':'Gaji_dalam_usd',
    'employee_residence':'Residence_karyawan',
    'remote_ratio':'Remoteness_ratio',
    'company_location':'Lokasi_perusahaan',
    'company_size':'Ukuran_perusahaan'
}, inplace=True)

# %%
df.head() # mengecek kembali apakah berhasil berubah/tidak
# Out:
#    Tahun_kerja Level_pengalaman Jenis_pekerjaan  \
# 0         2021               MI              FT
# 1         2021               MI              FT
# 2         2020               MI              FT
# 3         2021               MI              FT
# 4         2022               SE              FT
#
#                           Jabatan      Gaji Mata_uang  Gaji_dalam_usd  \
# 0                  Data Scientist  30400000       CLP           40038
# 1                 BI Data Analyst  11000000       HUF           36259
# 2                  Data Scientist  11000000       HUF           35735
# 3                     ML Engineer   8500000       JPY           77364
# 4  Lead Machine Learning Engineer   7500000       INR           95386
#
#   Residence_karyawan  Remoteness_ratio Lokasi_perusahaan Ukuran_perusahaan
# 0                 CL               100                CL                 L
# 1                 HU                50                US                 L
# ...

# %%
df['Level_pengalaman'].replace({ #Mengubah nama data di dalam baris, dengan tujuan agar lebih mudah di analisis
    'SE':'Senior',
    'MI':'Mid',
    'EN':'Entry',
    'EX':'Executive'
}, inplace=True)

#PERBEDAAN UTAMA NYA RENAME(UNTUK MENGUBAH NAMA DATA DI DALAM KOLOM DAN INDEX TABEL), SEDANGKAN UNTUK REPLACE(UNTUK MENGUBAH NAMA DATA DI DALAM TABEL)
# Out:
# <ipython-input-6-d1bcd5a1f14d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Level_pengalaman'].replace({ #Mengubah nama data di dalam baris, dengan tujuan agar lebih mudah di analisis

# %%
df['Jenis_pekerjaan'].replace({ #Mengubah nama data di dalam baris, dengan tujuan agar lebih mudah di analisis
    'FT':'Full Time',
    'PT':'Part Time',
    'CT':'Contract',
    'Fl':'Freelance'
}, inplace=True)
# Out:
# <ipython-input-7-a5f92fe5909f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Jenis_pekerjaan'].replace({ #Mengubah nama data di dalam baris, dengan tujuan agar lebih mudah di analisis

# %%
df.head()# mengecek kembali apakah berhasil berubah/tidak
# Out:
#    Tahun_kerja Level_pengalaman Jenis_pekerjaan  \
# 0         2021              Mid       Full Time
# 1         2021              Mid       Full Time
# 2         2020              Mid       Full Time
# 3         2021              Mid       Full Time
# 4         2022           Senior       Full Time
#
#                           Jabatan      Gaji Mata_uang  Gaji_dalam_usd  \
# 0                  Data Scientist  30400000       CLP           40038
# 1                 BI Data Analyst  11000000       HUF           36259
# 2                  Data Scientist  11000000       HUF           35735
# 3                     ML Engineer   8500000       JPY           77364
# 4  Lead Machine Learning Engineer   7500000       INR           95386
#
#   Residence_karyawan  Remoteness_ratio Lokasi_perusahaan Ukuran_perusahaan
# 0                 CL               100                CL                 L
# 1                 HU                50                US                 L
# ...

# %%
#MEMFILTER DATA DENGAN JABATAN KHUSUS UNTUK DATA SCIENTIST, SESUAI DENGAN TUJUAN ANALISIS INI

data_scientist= df.loc[ (df['Jabatan']=='Data Scientist'),#SYNTAX (loc [])DIGUNAKAN UNTUK MENGAKSES BARIS DAN KOLOM BERDASARKAN LABEL(NAMABARIS/NAMAKOLOM)
 ['Tahun_kerja',                                          #DENGAN KRITERIA TERTENTU(SESUAI TUJUAN)
  'Jabatan',
  'Jenis_pekerjaan',
  'Level_pengalaman',
  'Gaji_dalam_usd',
  'Mata_uang',
  'Lokasi_perusahaan',
  #MEMFILTER  KOLOOM/BARIS YG HANYA DIPERLUKAN SAJA UNTUK ANALISIS
]].sort_values(by='Gaji_dalam_usd', ascending=False)#SYNTAX (SORT_VALUES()) MERUPAKAN MENG SORTIR DATA /MENGURUTKAN DATA DARI YANG TERTINGGI MENUJU
#KE PALING KECIL, KARENA (ASCENDING=FALSE) ARTINYA DIURUTKAN DARI YG TERBESAR KE YG TERKECIL
#JIKA (ASCENDING=TRUE)MAKA DIURUTKAN DARI MULAI YG TERKECIL KE YG TERBESAR
data_scientist #PRINT
# Out:
#        Tahun_kerja         Jabatan Jenis_pekerjaan Level_pengalaman  \
# 76            2023  Data Scientist       Full Time           Senior
# 81            2024  Data Scientist       Full Time           Senior
# 78            2024  Data Scientist       Full Time           Senior
# 125           2020  Data Scientist       Full Time           Senior
# 139           2024  Data Scientist       Full Time              Mid
# ...            ...             ...             ...              ...
# 54            2022  Data Scientist       Full Time            Entry
# 7             2022  Data Scientist       Full Time            Entry
# 52            2023  Data Scientist       Full Time              Mid
# 60            2021  Data Scientist       Full Time              Mid
# 14830         2023  Data Scientist       Full Time            Entry
#
#        Gaji_dalam_usd Mata_uang Lokasi_perusahaan
# 76             750000       USD                US
# ...

# %% [markdown]
# # DATA GAJI SEBAGAI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME

# %%
#DATA GAJI DI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA EXECUTIVE)

Executive=data_scientist.loc[(data_scientist['Jenis_pekerjaan'] == 'Full Time') &(data_scientist['Level_pengalaman']== 'Executive'),
 ['Tahun_kerja',
  'Jabatan',
  'Level_pengalaman',
  'Gaji_dalam_usd',
  'Mata_uang',
  'Lokasi_perusahaan',
]].sort_values(by='Gaji_dalam_usd', ascending=False)#DIURUTKAN DARI BESAR KE KECIL
Executive
#MEMFILTER DENGAN SYARAT JENIS PEKERJAAN=FULLTIME, LEVEL PENGALAMAN=EXECUTIVE
# Out:
#        Tahun_kerja         Jabatan Level_pengalaman  Gaji_dalam_usd Mata_uang  \
# 464           2023  Data Scientist        Executive          300000       USD
# 474           2023  Data Scientist        Executive          299500       USD
# 942           2023  Data Scientist        Executive          258750       USD
# 943           2023  Data Scientist        Executive          258750       USD
# 1150          2023  Data Scientist        Executive          250000       USD
# 1191          2023  Data Scientist        Executive          249600       USD
# 1296          2024  Data Scientist        Executive          246100       USD
# 1770          2023  Data Scientist        Executive          228856       USD
# 1769          2023  Data Scientist        Executive          228856       USD
# 1898          2023  Data Scientist        Executive          225000       USD
# 2122          2023  Data Scientist        Executive          220000       USD
# ...

# %%
correlation = df['Gaji_dalam_usd'].corr(df['Tahun_kerja'])
print(correlation)
# Out:
# 0.09087347570331308

# %% [markdown]
# Cara memaknai koefisien korelasi:
#
# ▪ Semakin mendekati 0, dua kolom tidak berkorelasi.
#
# ▪ Semakin mendekati 1, dua kolom berbanding lurus.
#
# ▪ Semakin mendekati -1, dua kolom berbanding terbalik

# %%
Executive.groupby('Tahun_kerja')['Gaji_dalam_usd'].mean()# MENGHITUNG RATA RATA DARI DATA DIATAS DENGAN SYNTAX GROUPPBY DAN MEAN
# Out:
# Tahun_kerja
# 2022    144500.000000
# 2023    188562.344828
# 2024    165500.000000
# Name: Gaji_dalam_usd, dtype: float64

# %%
sns.barplot(
    data=Executive,
    x='Tahun_kerja',
    y='Gaji_dalam_usd',
    hue='Level_pengalaman',
   ci=None

).set(title=' GAJI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA EXECUTIVE)')#judul
#VISUALISASI DATA DENGAN MENGGUNAKAN LIBRARY BARPLOT DENGAN DATA EXECUTIVE
# Out:
# <ipython-input-13-73d8e5c30d3d>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# [Text(0.5, 1.0, ' GAJI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA EXECUTIVE)')]

# %%
#DATA GAJI DI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA SENIOR)

Senior=data_scientist.loc[(data_scientist['Jenis_pekerjaan'] == 'Full Time') &(data_scientist['Level_pengalaman']== 'Senior'),
 ['Tahun_kerja',
  'Jabatan',
  'Level_pengalaman',
  'Gaji_dalam_usd',
  'Mata_uang',
  'Lokasi_perusahaan',
]].sort_values(by='Gaji_dalam_usd', ascending=False)
Senior
#MEMFILTER DENGAN SYARAT JENIS PEKERJAAN=FULLTIME, LEVEL PENGALAMAN=senior
# Out:
#        Tahun_kerja         Jabatan Level_pengalaman  Gaji_dalam_usd Mata_uang  \
# 76            2023  Data Scientist           Senior          750000       USD
# 78            2024  Data Scientist           Senior          720000       USD
# 81            2024  Data Scientist           Senior          720000       USD
# 125           2020  Data Scientist           Senior          412000       USD
# 170           2023  Data Scientist           Senior          370000       USD
# ...            ...             ...              ...             ...       ...
# 14645         2022  Data Scientist           Senior           37824       EUR
# 14642         2022  Data Scientist           Senior           37824       EUR
# 14641         2022  Data Scientist           Senior           37824       EUR
# 14775         2024  Data Scientist           Senior           31250       GBP
# 4367          2021  Data Scientist           Senior           20171       TRY
#
#       Lokasi_perusahaan
# ...

# %%
#Menghitung Rata-rata dari Level pengalaman kerja

Senior.groupby('Tahun_kerja')['Gaji_dalam_usd'].mean().sort_values(ascending=False)
# Out:
# Tahun_kerja
# 2023    173480.984352
# 2020    172916.250000
# 2024    162411.981595
# 2022    151931.518519
# 2021     87071.250000
# Name: Gaji_dalam_usd, dtype: float64

# %%
sns.barplot(
    data=Senior,
    x='Tahun_kerja',
    y='Gaji_dalam_usd',
    hue='Level_pengalaman',
    ci=None
).set(title=' GAJI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA SENIOR)')
# Out:
# <ipython-input-16-bd3af8bd2585>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# [Text(0.5, 1.0, ' GAJI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA SENIOR)')]

# %% [markdown]
# DATA GAJI DI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA Mid)

# %%
Mid=data_scientist.loc[(data_scientist['Jenis_pekerjaan'] == 'Full Time') &(data_scientist['Level_pengalaman']== 'Mid'),
 ['Tahun_kerja',
  'Jabatan',
  'Level_pengalaman',
  'Gaji_dalam_usd',
  'Mata_uang',
  'Lokasi_perusahaan',
]].sort_values(by='Gaji_dalam_usd', ascending=False)
Mid
# Out:
#        Tahun_kerja         Jabatan Level_pengalaman  Gaji_dalam_usd Mata_uang  \
# 139           2024  Data Scientist              Mid          385000       USD
# 347           2024  Data Scientist              Mid          310000       USD
# 348           2023  Data Scientist              Mid          310000       USD
# 503           2023  Data Scientist              Mid          296980       USD
# 851           2023  Data Scientist              Mid          260600       USD
# ...            ...             ...              ...             ...       ...
# 14804         2021  Data Scientist              Mid           25532       EUR
# 14780         2022  Data Scientist              Mid           25000       USD
# 65            2023  Data Scientist              Mid           24613       THB
# 52            2023  Data Scientist              Mid           17025       INR
# 60            2021  Data Scientist              Mid           16904       INR
#
#       Lokasi_perusahaan
# ...

# %%
Mid.groupby('Tahun_kerja')['Gaji_dalam_usd'].mean().sort_values(ascending=False)
# Out:
# Tahun_kerja
# 2024    135024.984227
# 2023    124881.494545
# 2022     99188.440000
# 2021     83348.173913
# 2020     71256.000000
# Name: Gaji_dalam_usd, dtype: float64

# %%
sns.barplot(
    data=Mid,
    x='Tahun_kerja',
    y='Gaji_dalam_usd',
    hue='Level_pengalaman',
    ci=None
).set(title=' GAJI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA MID)')
# Out:
# <ipython-input-19-0d443af1dfa4>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# [Text(0.5, 1.0, ' GAJI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA MID)')]

# %% [markdown]
# DATA GAJI DI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA Entry)

# %%
#DATA GAJI DI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA Entry)

Entry=data_scientist.loc[(data_scientist['Jenis_pekerjaan'] == 'Full Time') &(data_scientist['Level_pengalaman']== 'Entry'),
 ['Tahun_kerja',
  'Jabatan',
  'Level_pengalaman',
  'Gaji_dalam_usd',
  'Mata_uang',
  'Lokasi_perusahaan',
]].sort_values(by='Gaji_dalam_usd', ascending=False)
Entry
# Out:
#        Tahun_kerja         Jabatan Level_pengalaman  Gaji_dalam_usd Mata_uang  \
# 3629          2023  Data Scientist            Entry          190000       USD
# 4350          2022  Data Scientist            Entry          180000       USD
# 4335          2022  Data Scientist            Entry          180000       USD
# 4556          2024  Data Scientist            Entry          175100       USD
# 4557          2024  Data Scientist            Entry          175100       USD
# ...            ...             ...              ...             ...       ...
# 11156         2023  Data Scientist            Entry           19910       BRL
# 14824         2023  Data Scientist            Entry           19434       EUR
# 54            2022  Data Scientist            Entry           17805       INR
# 7             2022  Data Scientist            Entry           17684       HUF
# 14830         2023  Data Scientist            Entry           16000       USD
#
#       Lokasi_perusahaan
# ...

# %%
Entry.groupby('Tahun_kerja')['Gaji_dalam_usd'].mean().sort_values(ascending=False)
# Out:
# Tahun_kerja
# 2023    93537.952381
# 2024    92477.000000
# 2022    79514.851852
# 2021    63604.333333
# 2020    61646.200000
# Name: Gaji_dalam_usd, dtype: float64

# %%
sns.barplot(
    data=Entry,
    x='Tahun_kerja',
    y='Gaji_dalam_usd',
    hue='Level_pengalaman',
    ci=None
).set(title=' GAJI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA Entry)')
# Out:
# <ipython-input-22-f521f5c6ddc6>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# [Text(0.5, 1.0, ' GAJI DATA SCIENTIST DENGAN JENIS PEKERJAAN FULL TIME (LEVEL PENGLAMAN KERJA Entry)')]

# %% [markdown]
# #DATA GAJI DI DATA SCIENTIST DENGAN JENIS PEKERJAAN CONTRACT (LEVEL PENGLAMAN KERJA EXECUTIVE, MID, ENTRY TIDAK ADA)

# %%
#DATA GAJI DI DATA SCIENTIST DENGAN JENIS PEKERJAAN CONTRACT (LEVEL PENGLAMAN KERJA Senior)

Senior=data_scientist.loc[(data_scientist['Jenis_pekerjaan'] == 'Contract') &(data_scientist['Level_pengalaman']== 'Senior'),
 ['Tahun_kerja',
  'Jabatan',
  'Jenis_pekerjaan',
  'Level_pengalaman',
  'Gaji_dalam_usd',
  'Mata_uang',
  'Lokasi_perusahaan',
]].sort_values(by='Gaji_dalam_usd', ascending=False)
Senior
# Out:
#       Tahun_kerja         Jabatan Jenis_pekerjaan Level_pengalaman  \
# 3512         2024  Data Scientist        Contract           Senior
# 9519         2024  Data Scientist        Contract           Senior
#
#       Gaji_dalam_usd Mata_uang Lokasi_perusahaan
# 3512          191027       USD                US
# 9519          120869       USD                US

# %%
Senior.groupby('Tahun_kerja')['Gaji_dalam_usd'].mean()
# Out:
# Tahun_kerja
# 2024    155948.0
# Name: Gaji_dalam_usd, dtype: float64

# %%
sns.barplot(
    data=Senior,
    x='Tahun_kerja',
    y='Gaji_dalam_usd',
    hue='Level_pengalaman',
    ci=None
)
# Out:
# <ipython-input-25-3df36e7406ce>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='Tahun_kerja', ylabel='Gaji_dalam_usd'>

# %% [markdown]
# # TIDAK ADA DATA DARI JENIS PEKERJAAN FREELANCE, DAN PARTIME(HANYA ADA CONTRACT)

# %% [markdown]
# # STATISTIK

# %%
rata=data_scientist.groupby('Tahun_kerja')['Gaji_dalam_usd'].mean().sort_values(ascending=False)
rata
#menghitung rata rata gaji sebagai data scientist dari tahun 2020-2024 di seluruh dunia, dan diurutkan dari yg terbesar
# Out:
# Tahun_kerja
# 2023    162890.935710
# 2024    149994.810489
# 2022    136902.710396
# 2020     85970.523810
# 2021     79650.425000
# Name: Gaji_dalam_usd, dtype: float64

# %% [markdown]
# RATA RATA GAJI DATA SCIENTIST BERDASARKAN LEVEL PENGALAMAN DARI TAHUN 2020-2024

# %%
rata_rata= data_scientist.groupby('Level_pengalaman')['Gaji_dalam_usd'].mean().sort_values(ascending=False)
rata_rata
#menghitung rata rata gaji sebagai data scientist dari tahun 2020-2024 di seluruh dunia, dan diurutkan dari yg terbesar
# Out:
# Level_pengalaman
# Executive    182440.756757
# Senior       167625.925303
# Mid          124480.467236
# Entry         87028.373134
# Name: Gaji_dalam_usd, dtype: float64

# %%
sns.barplot(
    data=data_scientist,
    y='Level_pengalaman',
    x='Gaji_dalam_usd',
    hue='Level_pengalaman',
    ci=None

).set(title=' GAJI DATA SCIENTIST DARI JENIS PEKERJAAN')
#hasil dari data sebelmnya, di visualisasikan
# Out:
# <ipython-input-28-475d540a98ec>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# [Text(0.5, 1.0, ' GAJI DATA SCIENTIST DARI JENIS PEKERJAAN')]

# %% [markdown]
# **Menghitung percentile (10%, 25%, 50%, 75%, 90%)**

# %%
percentile=data_scientist.groupby('Level_pengalaman')['Gaji_dalam_usd'].quantile([0.1,0.25,0.5,0.75,0.9]) #menghitung percentile
percentile
# Out:
# Level_pengalaman
# Entry             0.10     32974.00
#                   0.25     51141.00
#                   0.50     81000.00
#                   0.75    119800.00
#                   0.90    150000.00
# Executive         0.10    112166.40
#                   0.25    144540.00
#                   0.50    181900.00
#                   0.75    225000.00
#                   0.90    253500.00
# Mid               0.10     61472.30
#                   0.25     86144.25
#                   0.50    120000.00
#                   0.75    160000.00
#                   0.90    194080.00
# Senior            0.10    101050.00
#                   0.25    130000.00
#                   0.50    160350.00
#                   0.75    198440.00
#                   0.90    239000.00
# Name: Gaji_dalam_usd, dtype: float64

# %%
percentile = percentile.reset_index()# mengubah Pandas Series menjadi Pandas DataFrame. karena seaborn membutuhkan data dalam bentuk dataframe, bukan series.

# %%
sns.barplot(
    data=percentile,
    x='Level_pengalaman',
    y='Gaji_dalam_usd',
    hue='Gaji_dalam_usd',
    ci=None
).set(title='Percentile (10%, 25%, 50%, 75%, 90%) ')
# Out:
# <ipython-input-31-d716c7c76e60>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# [Text(0.5, 1.0, 'Percentile (10%, 25%, 50%, 75%, 90%) ')]

# %% [markdown]
# **Menghitung ekstremum minimal dan maximal**

# %%
#menghitung data ekstremum dari data diatas
minmax=data_scientist.groupby('Level_pengalaman')['Gaji_dalam_usd'].agg(['min','max']).sort_values(by='min', ascending=False)#mengitung min dan max dari gaji sebagai data scientist
minmax
# Out:
#                     min     max
# Level_pengalaman
# Executive         78000  300000
# Senior            20171  750000
# Mid               16904  385000
# Entry             16000  190000

# %%
#visualisasi dalam  data ekstremum minimal

sns.barplot(
    data=minmax,
    x='Level_pengalaman',
    y='min',
    hue='Level_pengalaman',
    ci=None
).set(title='Ekstremum minimal')
# Out:
# <ipython-input-33-e133773708dd>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# [Text(0.5, 1.0, 'Ekstremum minimal')]

# %%
#visualisasi dalam  data ekstremum maximal
sns.barplot(
    data=minmax,
    x='Level_pengalaman',
    y='max',
    hue='Level_pengalaman',
    ci=None
).set(title='Ekstremum maximal')
# Out:
# <ipython-input-34-b5e41afa8269>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# [Text(0.5, 1.0, 'Ekstremum maximal')]

# %% [markdown]
# MENGHITUNG DISTRIBUSI FREKUENSI

# %%
frequency_table = data_scientist['Tahun_kerja'].value_counts().reset_index()
frequency_table.columns = ['Tahun_kerja', 'Frekuensi']
print(frequency_table)# MENGHITUNG JUMLAH PEKERJA SEBAGAI DATA SCIENTIST DARI TAHUN 2020-2024
# Out:
#    Tahun_kerja  Frekuensi
# 0         2023       1711
# 1         2024        839
# 2         2022        404
# 3         2021         40
# 4         2020         21

# %%
#visualisasi jumlah pekerja data scientist dari tahun 2020-2024

sns.barplot(
    data=frequency_table,
    x='Tahun_kerja',
    y='Frekuensi',
    hue='Frekuensi',
    ci=None
).set(title='JUMLAH PEKERJA DATA SCIENTIST DARI TAHUN 2020-2024')
# Out:
# <ipython-input-36-2b18bd0d23aa>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# [Text(0.5, 1.0, 'JUMLAH PEKERJA DATA SCIENTIST DARI TAHUN 2020-2024')]

# %%
statistics = data_scientist.describe()
print(statistics)
# Out:
#        Tahun_kerja  Gaji_dalam_usd
# count  3015.000000     3015.000000
# mean   2023.096849   154179.810945
# std       0.720291    62296.323021
# min    2020.000000    16000.000000
# 25%    2023.000000   115000.000000
# 50%    2023.000000   150120.000000
# 75%    2024.000000   187229.500000
# max    2024.000000   750000.000000

# %% [markdown]
# Menghitung standar deviasi tahun 2020

# %%
standard_deviation = data_scientist.loc[data_scientist['Tahun_kerja'] == 2020, 'Gaji_dalam_usd'].std()
print(standard_deviation)
# Out:
# 81436.64871089616

# %% [markdown]
# Menghitung standar deviasi tahun 2021

# %%
standard_deviation = data_scientist.loc[data_scientist['Tahun_kerja'] == 2021, 'Gaji_dalam_usd'].std()
print(standard_deviation)
# Out:
# 40573.319274722766

# %% [markdown]
# Menghitung Standar deviasi tahun 2022

# %%
standard_deviation = data_scientist.loc[data_scientist['Tahun_kerja'] == 2022, 'Gaji_dalam_usd'].std()
print(standard_deviation)
# Out:
# 53191.03555578297

# %% [markdown]
# Menghitung standar deviasi tahun 2023

# %%
standard_deviation = data_scientist.loc[data_scientist['Tahun_kerja'] == 2023, 'Gaji_dalam_usd'].std()
print(standard_deviation)
# Out:
# 61794.28254661448

# %% [markdown]
# Menghitung standar deviasi tahun 2024

# %%
standard_deviation = data_scientist.loc[data_scientist['Tahun_kerja'] == 2024, 'Gaji_dalam_usd'].std()
print(standard_deviation)
# Out:
# 62228.69676062714

# %% [markdown]
# Menghitung standar deviasi dari tahun 2020-2024

# %%
#menghitung standar deviasi
standard_deviation = data_scientist['Gaji_dalam_usd'].std()
print(standard_deviation)
# Out:
# 62296.32302064552

# %% [markdown]
# #KORELASI

# %%
correlation = df['Gaji_dalam_usd'].corr(df['Tahun_kerja'])
print(correlation)
# Out:
# 0.09087347570331308

# %% [markdown]
# Cara memaknai koefisien korelasi:
#
# ▪ Semakin mendekati 0, dua kolom tidak berkorelasi.
#
# ▪ Semakin mendekati 1, dua kolom berbanding lurus.
#
# ▪ Semakin mendekati -1, dua kolom berbanding terbalik

# %% [markdown]
# #  CEK DATA APAKAH BERSIH/KOTOR

# %%
df.info()




#tidak ada data yang null, maka untuk kesuluruhan data sudah bersih
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Tahun_kerja         14838 non-null  int64
#  1   Level_pengalaman    14838 non-null  object
#  2   Jenis_pekerjaan     14838 non-null  object
#  3   Jabatan             14838 non-null  object
#  4   Gaji                14838 non-null  int64
#  5   Mata_uang           14838 non-null  object
#  6   Gaji_dalam_usd      14838 non-null  int64
#  7   Residence_karyawan  14838 non-null  object
#  8   Remoteness_ratio    14838 non-null  int64
#  9   Lokasi_perusahaan   14838 non-null  object
#  10  Ukuran_perusahaan   14838 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.2+ MB

# %%
data_scientist.info()


#INDEX DATA SCIENTIST HANYA MEMILIKI 3015 ROW DENGAN 7 KOLOM
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3015 entries, 76 to 14830
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tahun_kerja        3015 non-null   int64
#  1   Jabatan            3015 non-null   object
#  2   Jenis_pekerjaan    3015 non-null   object
#  3   Level_pengalaman   3015 non-null   object
#  4   Gaji_dalam_usd     3015 non-null   int64
#  5   Mata_uang          3015 non-null   object
#  6   Lokasi_perusahaan  3015 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 188.4+ KB

# %%
df.isnull().sum()

#TIDAK ADA YANG NULL, MAKA DIPASTIKAN DATA SUDAH BERSIH
# Out:
# Tahun_kerja           0
# Level_pengalaman      0
# Jenis_pekerjaan       0
# Jabatan               0
# Gaji                  0
# Mata_uang             0
# Gaji_dalam_usd        0
# Residence_karyawan    0
# Remoteness_ratio      0
# Lokasi_perusahaan     0
# Ukuran_perusahaan     0
# dtype: int64
